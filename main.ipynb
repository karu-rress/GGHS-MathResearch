# %%
from analyze import analyzer
from survey import surveyer

# %%
service = analyzer()
service.show_region()
service.scatter()
# Out:
# ['양평군', '파주시', '광명시', '안양시', '구리시', '하남시', '안산시', '성남시', '수원시', '의왕시', '동두천시', '안성시', '용인시', '고양시', '남양주시', '시흥시', '연천군', '화성시', '군포시', '평택시', '포천시', '김포시', '과천시', '이천시', '부천시', '양주시', '오산시', '의정부시', '여주시', '가평군', '광주시']

# %%
service2 = surveyer()
service2.show_needed()
service2.show_is_needed()
# Out:
# 국어
# 영어
# 수학
# 수학
# 수학
# 영어
# 수학
# 수학
# 수학
# 국어
# 영어
# 수학
# 수학
# 수학
# 수학
# 영어
# 수학
# 수학
# 수학
# 필요없다고 생각한다.
# 국어
# 영어
# 수학
# 국어
# 수학
# 예체능
# 수학
# 수학
# 수학
# 수학
# 수학
# 수학
# 영어
# 수학
# 영어
# 수학
# 영어
# 수학
# 국어
# 영어
# 수학
# 수학
# 수학
# 수학
# 수학
# 국어
# 영어
# 수학
# 과학
# 수학
# 수학
# 수학
# 수학
# 수학
# 수학
# 영어
# 수학
# [6, 11, 37, 1, 1]
